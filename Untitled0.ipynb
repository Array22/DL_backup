# %% [markdown]
# <a href="https://colab.research.google.com/github/Array22/DL_backup/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setup
# This only needs to be run once upon creation of notebook

# %%
# Save Dataset to Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Import Dataset into google drive
# !git clone https://github.com/JJsnowx/UIEB_Dataset "/content/drive/MyDrive/dataset"

# Import TCTL Code into google drive
# !git clone https://github.com/trentqq/TCTL-Net "/content/drive/MyDrive/TCTL"
# Out:
# Mounted at /content/drive

# %%
import os
import shutil

source_dir = [
    "/content/drive/MyDrive/dataset/UIEB Dataset/reference/UIEB_reference_reName",
    "/content/drive/MyDrive/dataset/UIEB Dataset/raw/UIEB_raw_reName"
]

destination_dir = [
    "/content/drive/MyDrive/TCTL/data/ref",
    "/content/drive/MyDrive/TCTL/data/raw"
]

for src, dst in zip(source_dir, destination_dir):

    if not os.path.isdir(src):
        print(f"Error: Source directory does not exist: {src}")
        continue

    os.makedirs(dst, exist_ok=True)

    for item in os.listdir(src):
        src_path = os.path.join(src, item)
        dst_path = os.path.join(dst, item)

        if os.path.isdir(src_path):
            shutil.copytree(src_path, dst_path, dirs_exist_ok=True)
        else:
            shutil.copy2(src_path, dst_path)

    print(f"Copied: {src}")
    print(f"     → {dst}")
# Out:
# Copied: /content/drive/MyDrive/dataset/UIEB Dataset/reference/UIEB_reference_reName
#      → /content/drive/MyDrive/TCTL/data/ref
# Copied: /content/drive/MyDrive/dataset/UIEB Dataset/raw/UIEB_raw_reName
#      → /content/drive/MyDrive/TCTL/data/raw

# %%
# %cd /content/drive/MyDrive/TCTL
os.makedirs("./checkpoint/test_run", exist_ok=True)

# Optional Pre-trained model:
# Put trained model into above folder. Download from https://github.com/trentqq/TCTL-Net

# %%
# Optional: For Safety

# Lines 25-26 in train.py
"""
Change:
    if args.continue_train:
        net.load_state_dict(torch.load(os.path.join(args.model_path, args.name, 'net_latest.pth')))
To:
    if args.continue_train:
        net.load_state_dict(torch.load(os.path.join(args.model_path, args.name, 'net_latest.pth'),
        weights_only=True))

"""

# Do the same for Line 30 on test.py

# %%
# Generating txt files (color transfer parameters)

import os
import cv2
import numpy as np

ref_dir = "/content/drive/MyDrive/TCTL/data/ref"
txt_dir = "/content/drive/MyDrive/TCTL/data/txt"

output_size = (256, 256)

os.makedirs(txt_dir, exist_ok=True)

image_extensions = {".jpg", ".jpeg", ".png", ".bmp", ".tif", ".tiff"}

for filename in sorted(os.listdir(ref_dir)):

    name, ext = os.path.splitext(filename)

    if ext.lower() not in image_extensions:
        continue

    path = os.path.join(ref_dir, filename)

    # Read reference image exactly like original code
    img = cv2.imread(path)

    if img is None:
        print(f"WARNING: Could not read {filename}")
        continue

    # Resize to 256x256, matching output_size in TrainDataset
    img = cv2.resize(img, output_size)

    # Convert uint8 BGR [0,255] -> float32 BGR [0,1]
    img = img.astype(np.float32) / 255.0

    # Convert to Lab exactly like original code
    lab = cv2.cvtColor(img, cv2.COLOR_BGR2LAB)

    # Calculate mean and std exactly like trans_np()
    mean = np.mean(lab, axis=(0, 1))
    std = np.std(lab, axis=(0, 1))

    # IMPORTANT:
    # Network expects:
    # [L_mean, A_mean, B_mean, L_std, A_std, B_std]
    true_num = np.concatenate([mean, std])

    txt_path = os.path.join(txt_dir, name + ".txt")

    with open(txt_path, "w") as f:
        f.write(",".join(f"{x:.10f}" for x in true_num))

    print(f"{filename}")
    print(f"  mean: {mean}")
    print(f"  std : {std}")
    print(f"  TXT : {txt_path}")

print("\nDone.")

# %% [markdown]
# # Startup
# Run everytime you start new notebook session

# %%
# # Mount google drive
from google.colab import drive
drive.mount('/content/drive')

# Install thop module
# !pip install thop
# Out:
# Mounted at /content/drive
# Collecting thop
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.13/dist-packages (from thop) (2.11.0+cu128)
# Requirement already satisfied: filelock in /usr/local/lib/python3.13/dist-packages (from torch->thop) (3.32.4)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.13/dist-packages (from torch->thop) (4.16.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.13/dist-packages (from torch->thop) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.13/dist-packages (from torch->thop) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.13/dist-packages (from torch->thop) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.13/dist-packages (from torch->thop) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.13/dist-packages (from torch->thop) (2025.3.0)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->thop) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.13/dist-packages (from torch->thop) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.13/dist-packages (from torch->thop) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.13/dist-packages (from torch->thop) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.13/dist-packages (from torch->thop) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.13/dist-packages (from torch->thop) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.13/dist-packages (from torch->thop) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->thop) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->thop) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->thop) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->thop) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->thop) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->thop) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->thop) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->thop) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->thop) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->thop) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->thop) (12.8.90)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.13/dist-packages (from cuda-bindings<13,>=12.9.4->torch->thop) (1.7.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from sympy>=1.13.3->torch->thop) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.13/dist-packages (from jinja2->torch->thop) (3.0.3)
# Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Installing collected packages: thop
# Successfully installed thop-0.1.1.post2209072238

# %% [markdown]
# # Training

# %%
# Make sure you're running Cuda: Runtime -> select GPU

# %cd /content/drive/MyDrive/TCTL
# !python train.py --dataroot data --name train_run --epochs 1

# provides UserWarning that default worker processes hurts performance.
# Out:
# /content/drive/MyDrive/TCTL
# /usr/local/lib/python3.13/dist-packages/torch/utils/data/dataloader.py:424: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# using cuda:0 device.
# start training:train_run
# /usr/local/lib/python3.13/dist-packages/torch/utils/data/dataloader.py:432: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# step:0, train epoch[1/1] total_loss:1891.9537353515625  l1_loss:170.86373901367188 mse:1621.7724609375
# save Training model epoch0
# Finished Training

# %%
# Runs faster when num_workers set to 2.

# %cd /content/drive/MyDrive/TCTL
# !python train.py --dataroot data --name train_run --epochs 2 --num_workers 2

# %% [markdown]
# # Testing

# %%
# %cd /content/drive/MyDrive/TCTL
# !python test.py --dataroot data --name test_run --num_workers 2
