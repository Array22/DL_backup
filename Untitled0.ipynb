# %% [markdown]
# <a href="https://colab.research.google.com/github/Array22/DL_backup/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Moving Files

# %%
import os


source_dir = "/content/UIEB_Dataset/UIEB_Dataset/reference/UIEB_reference_reName"
destination_dir = "/content/TCTL-Net/data/ref"

# Check if the source directory exists
if not os.path.exists(source_dir):
    print(f"Error: Source directory '{source_dir}' does not exist. Please ensure the directory is correctly named and mounted.")
elif not os.path.isdir(source_dir):
    print(f"Error: '{source_dir}' exists but is not a directory. Cannot move its contents.")
else:
    # Ensure the destination directory exists. `mkdir -p` is safe and idempotent.
    # !mkdir -p {destination_dir}

    # Move all contents (files and subdirectories) from the source directory
    # to the destination directory. The '*' ensures we move contents, not the directory itself.
    # !mv {source_dir}/* {destination_dir}/

# %%
# Navigate to the TCTL-Net directory if not already there
# %cd /content/TCTL-Net

# Run the test.py script with the correct dataroot and a chosen name
# !python test.py --dataroot data --name test_run
# Out:
# /content/TCTL-Net
# /usr/local/lib/python3.13/dist-packages/torch/utils/data/dataloader.py:424: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
#   0% 0/890 [00:00<?, ?it/s]/usr/local/lib/python3.13/dist-packages/torch/utils/data/dataloader.py:432: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
# ...

# %%
# !nvidia-smi
# Out:
# Mon Sep  7 05:54:15 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   50C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...
